# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fitness_df = pd.read_csv("athletes.csv")
fitness_df
# Out:
#         athlete_id             name               region  \
# 0           2554.0        Pj Ablang           South West
# 1           3517.0    Derek Abdella                  NaN
# 2           4691.0              NaN                  NaN
# 3           5164.0      Abo Brandon  Southern California
# 4           5286.0      Bryce Abbey                  NaN
# ...            ...              ...                  ...
# 423001    574489.0       Odo Renata        Latin America
# 423002    585696.0    Lozzie Trevor            Australia
# 423003    608828.0    Marisol Smith           North West
# 423004    628881.0  Pedrini Morgane               Europe
# 423005    631847.0       Eden Kenny  Northern California
#
#                            team              affiliate  gender   age  height  \
# 0                   Double Edge   Double Edge CrossFit    Male  24.0    70.0
# 1                           NaN                    NaN    Male  42.0    70.0
# ...

# %%
#creation and cleaning of deadlift by age
age_deadlift_df = pd.DataFrame(fitness_df['age']) #adding age to dataframe
age_deadlift_df = age_deadlift_df.join(fitness_df['deadlift']) # joining deadlift
age_deadlift_df = age_deadlift_df.dropna() # dropping nan values
age_deadlift_df = age_deadlift_df[age_deadlift_df['deadlift']<1200] #cleaning lift data
age_deadlift_df = age_deadlift_df[age_deadlift_df['age']<60] #cleaning age data
age_deadlift_df = age_deadlift_df[age_deadlift_df['deadlift']>50] #setting minimum deadlift

#linear regression (simple edition)
x, y = age_deadlift_df['age'].to_list(), age_deadlift_df['deadlift'].to_list()
coef = np.polyfit(x,y,1)
poly1d_fn = np.poly1d(coef) 
# poly1d_fn is now a function which takes in x and returns an estimate for y

plt.plot(x,y, 'co', x, poly1d_fn(x), '--k') #'--k'=black dashed line, 'yo' = yellow circle marker
plt.xlabel('age'), plt.ylabel('deadlift')
plt.xlim(0,60)
print(age_deadlift_df['deadlift'])
age_deadlift_df.groupby('age')['deadlift'].describe() #shows
# Out:
# 0         400.0
# 3         375.0
# 5         435.0
# 9         365.0
# 10        507.0
#           ...
# 422942    250.0
# 422944    165.0
# 422950    145.0
# 422961    240.0
# 423004     80.0
# Name: deadlift, Length: 111457, dtype: float64
#        count        mean         std    min     25%    50%     75%     max
# age
# 13.0     2.0  240.000000  190.918831  105.0  172.50  240.0  307.50   375.0
# 14.0    11.0  260.363636   48.660606  195.0  220.00  255.0  292.50   353.0
# 15.0    60.0  262.850000   68.291704  100.0  213.75  252.5  307.50   435.0
# 16.0   155.0  289.883871   81.698365  105.0  230.50  290.0  350.00   540.0
# 17.0   380.0  307.115789   84.115339  100.0  243.00  305.0  365.00   600.0
# 18.0   691.0  321.953690   87.487428   85.0  255.00  325.0  388.00   625.0
# 19.0  1064.0  336.977444   90.525878   75.0  265.00  345.0  405.00   595.0
# 20.0  1380.0  342.764493   95.165245   80.0  270.00  353.0  415.00   617.0
# ...

# %%
#creation and cleaning of 400m run between 40 and 150 seconds by age no greater than 60
age_run400_df = pd.DataFrame(fitness_df['age']) #ading age to dataframe
age_run400_df = age_run400_df.join(fitness_df['run400']) # joining 
age_run400_df = age_run400_df.dropna() # dropping nan values
age_run400_df = age_run400_df[age_run400_df['run400']<150] #cleaning maximum
age_run400_df = age_run400_df[age_run400_df['age']<690] #cleaning age data
age_run400_df = age_run400_df[age_run400_df['run400']>40] #setting minimum 

#linear regression (simple edition)
x, y = age_run400_df['age'].to_list(), age_run400_df['run400'].to_list()
coef = np.polyfit(x,y,1)
poly1d_fn = np.poly1d(coef) 
# poly1d_fn is now a function which takes in x and returns an estimate for y

plt.plot(x,y, 'co', x, poly1d_fn(x), '--k') #'--k'=black dashed line, 'yo' = yellow circle marker
plt.xlabel('age'), plt.ylabel('run400')
plt.xlim(0,60)

age_run400_df.groupby('age')['run400'].describe()
# Out:
#        count       mean        std   min    25%   50%    75%    max
# age
# 13.0     1.0  82.000000        NaN  82.0  82.00  82.0  82.00   82.0
# 14.0     2.0  65.000000   9.899495  58.0  61.50  65.0  68.50   72.0
# 15.0    14.0  72.357143  15.259837  54.0  60.50  69.0  81.50  107.0
# 16.0    35.0  68.142857  13.521536  50.0  58.50  65.0  72.50  114.0
# 17.0   104.0  68.826923  15.047783  42.0  58.00  64.5  78.00  120.0
# 18.0   139.0  68.381295  13.686657  45.0  59.00  65.0  73.00  126.0
# 19.0   192.0  68.177083  13.879432  47.0  59.00  65.5  74.25  135.0
# 20.0   271.0  68.191882  15.364705  49.0  58.00  64.0  75.00  143.0
# 21.0   341.0  68.070381  14.699371  45.0  58.00  64.0  74.00  130.0
# 22.0   448.0  67.814732  13.764528  45.0  59.00  65.0  74.00  120.0
# 23.0   594.0  69.353535  15.580166  45.0  59.00  65.0  75.00  143.0
# 24.0   800.0  70.112500  15.111926  42.0  60.00  66.0  77.00  138.0
# 25.0   888.0  70.504505  14.926425  48.0  60.00  67.0  78.00  145.0
# ...

# %%
#creation and cleaning of 4005k run between 400 and 9000 seconds by age no greater than 60
age_run5k_df = pd.DataFrame(fitness_df['age']) #adding age to dataframe
age_run5k_df = age_run5k_df.join(fitness_df['run5k']) # joining 
age_run5k_df = age_run5k_df.dropna() # dropping nan values
age_run5k_df = age_run5k_df[age_run5k_df['run5k']<9000] #cleaning maximum
age_run5k_df = age_run5k_df[age_run5k_df['age']<60] #cleaning age data
age_run5k_df = age_run5k_df[age_run5k_df['run5k']>400] #setting minimum 

#linear regression (simple edition)
x, y = age_run5k_df['age'].to_list(), age_run5k_df['run5k'].to_list()
coef = np.polyfit(x,y,1)
poly1d_fn = np.poly1d(coef) 
# poly1d_fn is now a function which takes in x and returns an estimate for y

plt.plot(x,y, 'co', x, poly1d_fn(x), '--k') #'--k'=black dashed line, 'yo' = yellow circle marker
plt.xlabel('age'), plt.ylabel('run5k')
plt.xlim(10,60)
plt.ylim(400,3000)

age_run5k_df.groupby('age')['run5k'].describe()
# Out:
#        count         mean         std     min      25%     50%      75%  \
# age
# 13.0     2.0  2031.000000  946.108873  1362.0  1696.50  2031.0  2365.50
# 14.0     3.0  1536.666667  205.947404  1305.0  1455.50  1606.0  1652.50
# 15.0    16.0  1345.000000  302.958303  1020.0  1200.00  1276.0  1389.00
# 16.0    31.0  1402.741935  306.083427  1064.0  1182.50  1279.0  1518.50
# 17.0    98.0  1376.602041  231.821818  1009.0  1201.25  1331.5  1508.00
# 18.0   162.0  1343.086420  248.632418   805.0  1177.00  1297.0  1440.00
# 19.0   241.0  1346.730290  361.561241   420.0  1174.00  1275.0  1472.00
# 20.0   330.0  1339.666667  251.903666   784.0  1172.00  1274.5  1440.00
# 21.0   492.0  1357.091463  321.301601   480.0  1189.75  1294.0  1475.25
# 22.0   701.0  1353.951498  265.833563   480.0  1185.00  1303.0  1475.00
# 23.0   894.0  1360.884787  273.925213   780.0  1192.00  1304.5  1471.00
# 24.0  1167.0  1379.853470  305.741101   563.0  1200.00  1320.0  1500.00
# ...

# %%
#creation and cleaning of weight between 60 and 400 by age no greater than 60
age_weight_df = pd.DataFrame(fitness_df['age']) #adding age to dataframe
age_weight_df = age_weight_df.join(fitness_df['weight']) # joining 
age_weight_df = age_weight_df.dropna() # dropping nan values
age_weight_df = age_weight_df[age_weight_df['weight']<400] #cleaning maximum
age_weight_df = age_weight_df[age_weight_df['age']<60] #cleaning age data
age_weight_df = age_weight_df[age_weight_df['weight']>50] #setting minimum 

#linear regression (simple edition)
x, y = age_weight_df['age'].to_list(), age_weight_df['weight'].to_list()
coef = np.polyfit(x,y,1)
poly1d_fn = np.poly1d(coef) 
#poly1d_fn is now a function which takes in x and returns an estimate for y

plt.plot(x,y, 'co', x, poly1d_fn(x), '--k') #'--k'=black dashed line, 'yo' = yellow circle marker
plt.xlabel('age'), plt.ylabel('weight')
plt.xlim(10,60)
plt.ylim(0,400)

age_weight_df.groupby('age')['weight'].describe()
# Out:
#         count        mean        std    min     25%    50%     75%    max
# age
# 13.0      4.0  142.000000  40.963398   92.0  116.75  150.0  175.25  176.0
# 14.0     19.0  141.105263  27.658422   99.0  118.50  140.0  151.00  199.0
# 15.0     98.0  144.683673  24.306716  105.0  128.25  140.0  158.00  250.0
# 16.0    245.0  152.183673  26.090380   67.0  135.00  150.0  167.00  272.0
# 17.0    835.0  155.265868  25.881462   75.0  136.00  154.0  172.50  320.0
# 18.0   1627.0  157.913337  28.611113   55.0  138.00  157.0  176.00  295.0
# 19.0   2167.0  162.524227  28.872107   57.0  142.00  163.0  180.00  330.0
# 20.0   3008.0  163.107048  29.238703   61.0  141.00  165.0  182.00  332.0
# 21.0   4120.0  162.755583  29.620128   55.0  140.00  163.0  183.00  355.0
# 22.0   5590.0  163.489267  29.874680   53.0  140.00  165.0  185.00  295.0
# 23.0   7336.0  164.787895  30.368291   53.0  141.00  165.0  185.00  378.0
# 24.0   9234.0  165.516461  31.313513   54.0  141.00  165.0  186.00  330.0
# ...
